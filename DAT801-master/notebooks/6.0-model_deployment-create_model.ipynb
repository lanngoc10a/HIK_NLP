# %% [markdown]
# # Introduction

# %% [markdown]
# In this notebook we'll use PyCaret to create and save a model. In the next notebook we'll deploy the model by creating a simple web app.

# %% [markdown]
# > **Note:** This is far from a comprehensive example of building machine learning-powered applications. We'll keep things very simple. The goal is to get some exposure to some main ideas from machine learning engineering and to some libraries that can be used to make simple prototype applications.

# %% [markdown]
# # Get the data

# %%
from pycaret.datasets import get_data

# %% [markdown]
# Here's a list of the data in the PyCaret repository. Remember that you could of course load the data from a CSV file or similar.

# %%
_ = get_data()
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# Let's select the `bike` data set. It's a bike-sharing data set where the goal is to predict the number of bike rentals given a set of features. See here for a description: https://archive.ics.uci.edu/ml/datasets/bike+sharing+dataset.

# %%
df = get_data('bike')
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
# 2        3  1/1/2011       1   0     1   2        0        6           0
# 3        4  1/1/2011       1   0     1   3        0        6           0
# 4        5  1/1/2011       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  cnt
# 0           1  0.24  0.2879  0.81        0.0   16
# 1           1  0.22  0.2727  0.80        0.0   40
# 2           1  0.22  0.2727  0.80        0.0   32
# 3           1  0.24  0.2879  0.75        0.0   13
# 4           1  0.24  0.2879  0.75        0.0    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  cnt         17379 non-null  int64
# dtypes: float64(4), int64(10), object(1)
# memory usage: 2.0+ MB

# %% [markdown]
# Here's a description of the features, copied from https://archive.ics.uci.edu/ml/datasets/bike+sharing+dataset.

# %% [markdown]
# ```
# - instant: record index
# - dteday : date
# - season : season (1:winter, 2:spring, 3:summer, 4:fall)
# - yr : year (0: 2011, 1:2012)
# - mnth : month ( 1 to 12)
# - hr : hour (0 to 23)
# - holiday : weather day is holiday or not (extracted from [Web Link])
# - weekday : day of the week
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# + weathersit :
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp : Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale)
# - atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
# - hum: Normalized humidity. The values are divided to 100 (max)
# - windspeed: Normalized wind speed. The values are divided to 67 (max)
# - casual: count of casual users
# - registered: count of registered users
# - cnt: count of total rental bikes including both casual and registered
# ```

# %% [markdown]
# What's the distribution of bike rental counts?

# %%
df.cnt.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Prepare data

# %% [markdown]
# We use PyCaret to automatically prepare the data for us (using the default settings of the `setup` function):

# %%
from pycaret.regression import *

# %%
clf = setup(df, target = 'cnt', ignore_features=['instant'])
# Out:
# <style type="text/css">
# #T_9a4e6_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9a4e6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a4e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a4e6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9a4e6_row0_col1" class="data row0 col1" >2286</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a4e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9a4e6_row1_col1" class="data row1 col1" >cnt</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a4e6_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_9a4e6_row2_col1" class="data row2 col1" >(17379, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a4e6_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_9a4e6_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a4e6_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_9a4e6_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9a4e6_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_9a4e6_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9a4e6_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_9a4e6_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9a4e6_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_9a4e6_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9a4e6_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_9a4e6_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9a4e6_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_9a4e6_row9_col1" class="data row9 col1" >(12165, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9a4e6_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_9a4e6_row10_col1" class="data row10 col1" >(5214, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9a4e6_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_9a4e6_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9a4e6_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_9a4e6_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9a4e6_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_9a4e6_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9a4e6_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_9a4e6_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9a4e6_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_9a4e6_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9a4e6_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_9a4e6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9a4e6_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_9a4e6_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9a4e6_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_9a4e6_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9a4e6_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_9a4e6_row19_col1" class="data row19 col1" >2b53</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9a4e6_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_9a4e6_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9a4e6_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_9a4e6_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9a4e6_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_9a4e6_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9a4e6_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_9a4e6_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9a4e6_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_9a4e6_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_9a4e6_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_9a4e6_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_9a4e6_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_9a4e6_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_9a4e6_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_9a4e6_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_9a4e6_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_9a4e6_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_9a4e6_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_9a4e6_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a4e6_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_9a4e6_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_9a4e6_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %% [markdown]
# # Modelling

# %% [markdown]
# Let's find the top performing models from those in PyCaret:

# %%
top5 = compare_models(n_select=5, sort='R2')
# Out:
# <style type="text/css">
# #T_3a0f1_ th {
#   text-align: left;
# }
# #T_3a0f1_row0_col0, #T_3a0f1_row0_col5, #T_3a0f1_row0_col6, #T_3a0f1_row1_col0, #T_3a0f1_row1_col1, #T_3a0f1_row1_col2, #T_3a0f1_row1_col3, #T_3a0f1_row1_col4, #T_3a0f1_row1_col5, #T_3a0f1_row1_col6, #T_3a0f1_row2_col0, #T_3a0f1_row2_col1, #T_3a0f1_row2_col2, #T_3a0f1_row2_col3, #T_3a0f1_row2_col4, #T_3a0f1_row2_col5, #T_3a0f1_row2_col6, #T_3a0f1_row3_col0, #T_3a0f1_row3_col1, #T_3a0f1_row3_col2, #T_3a0f1_row3_col3, #T_3a0f1_row3_col4, #T_3a0f1_row4_col0, #T_3a0f1_row4_col1, #T_3a0f1_row4_col2, #T_3a0f1_row4_col3, #T_3a0f1_row4_col4, #T_3a0f1_row4_col5, #T_3a0f1_row4_col6, #T_3a0f1_row5_col0, #T_3a0f1_row5_col1, #T_3a0f1_row5_col2, #T_3a0f1_row5_col3, #T_3a0f1_row5_col4, #T_3a0f1_row5_col5, #T_3a0f1_row5_col6, #T_3a0f1_row6_col0, #T_3a0f1_row6_col1, #T_3a0f1_row6_col2, #T_3a0f1_row6_col3, #T_3a0f1_row6_col4, #T_3a0f1_row6_col5, #T_3a0f1_row6_col6, #T_3a0f1_row7_col0, #T_3a0f1_row7_col1, #T_3a0f1_row7_col2, #T_3a0f1_row7_col3, #T_3a0f1_row7_col4, #T_3a0f1_row7_col5, #T_3a0f1_row7_col6, #T_3a0f1_row8_col0, #T_3a0f1_row8_col1, #T_3a0f1_row8_col2, #T_3a0f1_row8_col3, #T_3a0f1_row8_col4, #T_3a0f1_row8_col5, #T_3a0f1_row8_col6, #T_3a0f1_row9_col0, #T_3a0f1_row9_col1, #T_3a0f1_row9_col2, #T_3a0f1_row9_col3, #T_3a0f1_row9_col4, #T_3a0f1_row9_col5, #T_3a0f1_row9_col6, #T_3a0f1_row10_col0, #T_3a0f1_row10_col1, #T_3a0f1_row10_col2, #T_3a0f1_row10_col3, #T_3a0f1_row10_col4, #T_3a0f1_row10_col5, #T_3a0f1_row10_col6, #T_3a0f1_row11_col0, #T_3a0f1_row11_col1, #T_3a0f1_row11_col2, #T_3a0f1_row11_col3, #T_3a0f1_row11_col4, #T_3a0f1_row11_col5, #T_3a0f1_row11_col6, #T_3a0f1_row12_col0, #T_3a0f1_row12_col1, #T_3a0f1_row12_col2, #T_3a0f1_row12_col3, #T_3a0f1_row12_col4, #T_3a0f1_row12_col5, #T_3a0f1_row12_col6, #T_3a0f1_row13_col0, #T_3a0f1_row13_col1, #T_3a0f1_row13_col2, #T_3a0f1_row13_col3, #T_3a0f1_row13_col4, #T_3a0f1_row13_col5, #T_3a0f1_row13_col6, #T_3a0f1_row14_col0, #T_3a0f1_row14_col1, #T_3a0f1_row14_col2, #T_3a0f1_row14_col3, #T_3a0f1_row14_col4, #T_3a0f1_row14_col5, #T_3a0f1_row14_col6, #T_3a0f1_row15_col0, #T_3a0f1_row15_col1, #T_3a0f1_row15_col2, #T_3a0f1_row15_col3, #T_3a0f1_row15_col4, #T_3a0f1_row15_col5, #T_3a0f1_row15_col6, #T_3a0f1_row16_col0, #T_3a0f1_row16_col1, #T_3a0f1_row16_col2, #T_3a0f1_row16_col3, #T_3a0f1_row16_col4, #T_3a0f1_row16_col5, #T_3a0f1_row16_col6, #T_3a0f1_row17_col0, #T_3a0f1_row17_col1, #T_3a0f1_row17_col2, #T_3a0f1_row17_col3, #T_3a0f1_row17_col4, #T_3a0f1_row17_col5, #T_3a0f1_row17_col6, #T_3a0f1_row18_col0, #T_3a0f1_row18_col1, #T_3a0f1_row18_col2, #T_3a0f1_row18_col3, #T_3a0f1_row18_col4, #T_3a0f1_row18_col5, #T_3a0f1_row18_col6 {
#   text-align: left;
# }
# #T_3a0f1_row0_col1, #T_3a0f1_row0_col2, #T_3a0f1_row0_col3, #T_3a0f1_row0_col4, #T_3a0f1_row3_col5, #T_3a0f1_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3a0f1_row0_col7, #T_3a0f1_row1_col7, #T_3a0f1_row2_col7, #T_3a0f1_row3_col7, #T_3a0f1_row4_col7, #T_3a0f1_row5_col7, #T_3a0f1_row6_col7, #T_3a0f1_row7_col7, #T_3a0f1_row8_col7, #T_3a0f1_row9_col7, #T_3a0f1_row10_col7, #T_3a0f1_row11_col7, #T_3a0f1_row12_col7, #T_3a0f1_row13_col7, #T_3a0f1_row15_col7, #T_3a0f1_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3a0f1_row14_col7, #T_3a0f1_row17_col7, #T_3a0f1_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3a0f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a0f1_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_3a0f1_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_3a0f1_row0_col1" class="data row0 col1" >25.0843</td>
#       <td id="T_3a0f1_row0_col2" class="data row0 col2" >1602.2786</td>
#       <td id="T_3a0f1_row0_col3" class="data row0 col3" >39.9608</td>
#       <td id="T_3a0f1_row0_col4" class="data row0 col4" >0.9512</td>
#       <td id="T_3a0f1_row0_col5" class="data row0 col5" >0.4397</td>
#       <td id="T_3a0f1_row0_col6" class="data row0 col6" >0.4518</td>
#       <td id="T_3a0f1_row0_col7" class="data row0 col7" >0.3670</td>
#     </tr>
#     <tr>
#       <th id="T_3a0f1_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_3a0f1_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_3a0f1_row1_col1" class="data row1 col1" >26.4029</td>
#       <td id="T_3a0f1_row1_col2" class="data row1 col2" >1772.2188</td>
#       <td id="T_3a0f1_row1_col3" class="data row1 col3" >42.0506</td>
#       <td id="T_3a0f1_row1_col4" class="data row1 col4" >0.9460</td>
#       <td id="T_3a0f1_row1_col5" class="data row1 col5" >0.4473</td>
#       <td id="T_3a0f1_row1_col6" class="data row1 col6" >0.4441</td>
#       <td id="T_3a0f1_row1_col7" class="data row1 col7" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_3a0f1_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_3a0f1_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3a0f1_row2_col1" class="data row2 col1" >26.7381</td>
#       <td id="T_3a0f1_row2_col2" class="data row2 col2" >1792.5107</td>
#       <td id="T_3a0f1_row2_col3" class="data row2 col3" >42.2759</td>
#       <td id="T_3a0f1_row2_col4" class="data row2 col4" >0.9454</td>
#       <td id="T_3a0f1_row2_col5" class="data row2 col5" >0.4311</td>
#       <td id="T_3a0f1_row2_col6" class="data row2 col6" >0.4379</td>
#       <td id="T_3a0f1_row2_col7" class="data row2 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_3a0f1_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_3a0f1_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_3a0f1_row3_col1" class="data row3 col1" >25.8323</td>
#       <td id="T_3a0f1_row3_col2" class="data row3 col2" >1831.9215</td>
#       <td id="T_3a0f1_row3_col3" class="data row3 col3" >42.7298</td>
#       <td id="T_3a0f1_row3_col4" class="data row3 col4" >0.9441</td>
#       <td id="T_3a0f1_row3_col5" class="data row3 col5" >0.3404</td>
#       <td id="T_3a0f1_row3_col6" class="data row3 col6" >0.3171</td>
#       <td id="T_3a0f1_row3_col7" class="data row3 col7" >0.2130</td>
#     </tr>
#     <tr>
#       <th id="T_3a0f1_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_3a0f1_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_3a0f1_row4_col1" class="data row4 col1" >26.7572</td>
#       <td id="T_3a0f1_row4_col2" class="data row4 col2" >1989.5402</td>
#       <td id="T_3a0f1_row4_col3" class="data row4 col3" >44.5106</td>
#       <td id="T_3a0f1_row4_col4" class="data row4 col4" >0.9394</td>
#       <td id="T_3a0f1_row4_col5" class="data row4 col5" >0.3503</td>
#       <td id="T_3a0f1_row4_col6" class="data row4 col6" >0.3267</td>
#       <td id="T_3a0f1_row4_col7" class="data row4 col7" >0.1990</td>
#     </tr>
#     <tr>
#       <th id="T_3a0f1_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_3a0f1_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_3a0f1_row5_col1" class="data row5 col1" >36.1052</td>
#       <td id="T_3a0f1_row5_col2" class="data row5 col2" >3940.7579</td>
#       <td id="T_3a0f1_row5_col3" class="data row5 col3" >62.6779</td>
#       <td id="T_3a0f1_row5_col4" class="data row5 col4" >0.8797</td>
#       <td id="T_3a0f1_row5_col5" class="data row5 col5" >0.4466</td>
#       <td id="T_3a0f1_row5_col6" class="data row5 col6" >0.3867</td>
#       <td id="T_3a0f1_row5_col7" class="data row5 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_3a0f1_l

# %% [markdown]
# The natural next step would be to tune the top models (i.e. hyperparameter-tuning using grid search or random search). We skip this as it takes quite some time.

# %%
#tuned_top5 = [tune_model(i) for i in top5]

# %% [markdown]
# Let's create bagging ensembles for all our top 5 models:

# %%
bagged_top5 = [ensemble_model(i) for i in top5]
# Out:
# <style type="text/css">
# #T_a4d80_row10_col0, #T_a4d80_row10_col1, #T_a4d80_row10_col2, #T_a4d80_row10_col3, #T_a4d80_row10_col4, #T_a4d80_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a4d80_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4d80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4d80_row0_col0" class="data row0 col0" >28.0239</td>
#       <td id="T_a4d80_row0_col1" class="data row0 col1" >1934.2181</td>
#       <td id="T_a4d80_row0_col2" class="data row0 col2" >43.9797</td>
#       <td id="T_a4d80_row0_col3" class="data row0 col3" >0.9406</td>
#       <td id="T_a4d80_row0_col4" class="data row0 col4" >0.3360</td>
#       <td id="T_a4d80_row0_col5" class="data row0 col5" >0.3177</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4d80_row1_col0" class="data row1 col0" >26.5430</td>
#       <td id="T_a4d80_row1_col1" class="data row1 col1" >1701.9293</td>
#       <td id="T_a4d80_row1_col2" class="data row1 col2" >41.2544</td>
#       <td id="T_a4d80_row1_col3" class="data row1 col3" >0.9502</td>
#       <td id="T_a4d80_row1_col4" class="data row1 col4" >0.3640</td>
#       <td id="T_a4d80_row1_col5" class="data row1 col5" >0.3358</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4d80_row2_col0" class="data row2 col0" >28.1422</td>
#       <td id="T_a4d80_row2_col1" class="data row2 col1" >2037.5357</td>
#       <td id="T_a4d80_row2_col2" class="data row2 col2" >45.1391</td>
#       <td id="T_a4d80_row2_col3" class="data row2 col3" >0.9369</td>
#       <td id="T_a4d80_row2_col4" class="data row2 col4" >0.3632</td>
#       <td id="T_a4d80_row2_col5" class="data row2 col5" >0.3432</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4d80_row3_col0" class="data row3 col0" >27.0288</td>
#       <td id="T_a4d80_row3_col1" class="data row3 col1" >2048.6737</td>
#       <td id="T_a4d80_row3_col2" class="data row3 col2" >45.2623</td>
#       <td id="T_a4d80_row3_col3" class="data row3 col3" >0.9335</td>
#       <td id="T_a4d80_row3_col4" class="data row3 col4" >0.3664</td>
#       <td id="T_a4d80_row3_col5" class="data row3 col5" >0.3473</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4d80_row4_col0" class="data row4 col0" >28.7402</td>
#       <td id="T_a4d80_row4_col1" class="data row4 col1" >2363.2652</td>
#       <td id="T_a4d80_row4_col2" class="data row4 col2" >48.6134</td>
#       <td id="T_a4d80_row4_col3" class="data row4 col3" >0.9252</td>
#       <td id="T_a4d80_row4_col4" class="data row4 col4" >0.3826</td>
#       <td id="T_a4d80_row4_col5" class="data row4 col5" >0.3724</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a4d80_row5_col0" class="data row5 col0" >26.7254</td>
#       <td id="T_a4d80_row5_col1" class="data row5 col1" >1700.3880</td>
#       <td id="T_a4d80_row5_col2" class="data row5 col2" >41.2358</td>
#       <td id="T_a4d80_row5_col3" class="data row5 col3" >0.9482</td>
#       <td id="T_a4d80_row5_col4" class="data row5 col4" >0.3532</td>
#       <td id="T_a4d80_row5_col5" class="data row5 col5" >0.3316</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a4d80_row6_col0" class="data row6 col0" >27.4981</td>
#       <td id="T_a4d80_row6_col1" class="data row6 col1" >1836.2985</td>
#       <td id="T_a4d80_row6_col2" class="data row6 col2" >42.8521</td>
#       <td id="T_a4d80_row6_col3" class="data row6 col3" >0.9419</td>
#       <td id="T_a4d80_row6_col4" class="data row6 col4" >0.3741</td>
#       <td id="T_a4d80_row6_col5" class="data row6 col5" >0.3871</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4d80_row7_col0" class="data row7 col0" >27.6692</td>
#       <td id="T_a4d80_row7_col1" class="data row7 col1" >2267.1784</td>
#       <td id="T_a4d80_row7_col2" class="data row7 col2" >47.6149</td>
#       <td id="T_a4d80_row7_col3" class="data row7 col3" >0.9326</td>
#       <td id="T_a4d80_row7_col4" class="data row7 col4" >0.3824</td>
#       <td id="T_a4d80_row7_col5" class="data row7 col5" >0.4037</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a4d80_row8_col0" class="data row8 col0" >30.0130</td>
#       <td id="T_a4d80_row8_col1" class="data row8 col1" >2374.8284</td>
#       <td id="T_a4d80_row8_col2" class="data row8 col2" >48.7322</td>
#       <td id="T_a4d80_row8_col3" class="data row8 col3" >0.9352</td>
#       <td id="T_a4d80_row8_col4" class="data row8 col4" >0.3756</td>
#       <td id="T_a4d80_row8_col5" class="data row8 col5" >0.3625</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a4d80_row9_col0" class="data row9 col0" >27.1091</td>
#       <td id="T_a4d80_row9_col1" class="data row9 col1" >1925.9058</td>
#       <td id="T_a4d80_row9_col2" class="data row9 col2" >43.8851</td>
#       <td id="T_a4d80_row9_col3" class="data row9 col3" >0.9404</td>
#       <td id="T_a4d80_row9_col4" class="data row9 col4" >0.3430</td>
#       <td id="T_a4d80_row9_col5" class="data row9 col5" >0.3173</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a4d80_row10_col0" class="data row10 col0" >27.7493</td>
#       <td id="T_a4d80_row10_col1" class="data row10 col1" >2019.0221</td>
#       <td id="T_a4d80_row10_col2" class="data row10 col2" >44.8569</td>
#       <td id="T_a4d80_row10_col3" class="data row10 col3" >0.9385</td>
#       <td id="T_a4d80_row10_col4" class="data row10 col4" >0.3640</td>
#       <td id="T_a4d80_row10_col5" class="data row10 col5" >0.3519</td>
#     </tr>
#     <tr>
#       <th id="T_a4d80_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_a4d80_row11_col0" class="data row11 col0" >0.9919</td>
#       <td id="T_a4d80_row11_col1" class="data row11 col1" >236.4806</td>
#       <td id="T_a4d80_row11_col2" class="data row11 col2" >2.6230</td>
#       <td id="T_a4d80_row11_col3" class="data row11 col3" >0.0071</td>
#       <td id="T_a4d80_row11_col4" class="data row11 col4" >0.0151</td>
#       <td id="T_a4d80_row11_col5" class="data row11 col5" >0.0275</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can also try to blend the models (i.e., have them vote using a `VotingRegressor`):

# %%
blender = blend_models(estimator_list = top5)
# Out:
# <style type="text/css">
# #T_088fa_row10_col0, #T_088fa_row10_col1, #T_088fa_row10_col2, #T_088fa_row10_col3, #T_088fa_row10_col4, #T_088fa_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_088fa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_088fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_088fa_row0_col0" class="data row0 col0" >23.5342</td>
#       <td id="T_088fa_row0_col1" class="data row0 col1" >1386.4931</td>
#       <td id="T_088fa_row0_col2" class="data row0 col2" >37.2356</td>
#       <td id="T_088fa_row0_col3" class="data row0 col3" >0.9575</td>
#       <td id="T_088fa_row0_col4" class="data row0 col4" >0.3372</td>
#       <td id="T_088fa_row0_col5" class="data row0 col5" >0.2957</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_088fa_row1_col0" class="data row1 col0" >22.5282</td>
#       <td id="T_088fa_row1_col1" class="data row1 col1" >1301.3653</td>
#       <td id="T_088fa_row1_col2" class="data row1 col2" >36.0744</td>
#       <td id="T_088fa_row1_col3" class="data row1 col3" >0.9619</td>
#       <td id="T_088fa_row1_col4" class="data row1 col4" >0.3583</td>
#       <td id="T_088fa_row1_col5" class="data row1 col5" >0.3240</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_088fa_row2_col0" class="data row2 col0" >23.7823</td>
#       <td id="T_088fa_row2_col1" class="data row2 col1" >1550.0186</td>
#       <td id="T_088fa_row2_col2" class="data row2 col2" >39.3703</td>
#       <td id="T_088fa_row2_col3" class="data row2 col3" >0.9520</td>
#       <td id="T_088fa_row2_col4" class="data row2 col4" >0.3456</td>
#       <td id="T_088fa_row2_col5" class="data row2 col5" >0.3280</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_088fa_row3_col0" class="data row3 col0" >23.2216</td>
#       <td id="T_088fa_row3_col1" class="data row3 col1" >1593.5578</td>
#       <td id="T_088fa_row3_col2" class="data row3 col2" >39.9194</td>
#       <td id="T_088fa_row3_col3" class="data row3 col3" >0.9483</td>
#       <td id="T_088fa_row3_col4" class="data row3 col4" >0.3619</td>
#       <td id="T_088fa_row3_col5" class="data row3 col5" >0.3273</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_088fa_row4_col0" class="data row4 col0" >24.3552</td>
#       <td id="T_088fa_row4_col1" class="data row4 col1" >1736.2865</td>
#       <td id="T_088fa_row4_col2" class="data row4 col2" >41.6688</td>
#       <td id="T_088fa_row4_col3" class="data row4 col3" >0.9450</td>
#       <td id="T_088fa_row4_col4" class="data row4 col4" >0.3612</td>
#       <td id="T_088fa_row4_col5" class="data row4 col5" >0.3294</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_088fa_row5_col0" class="data row5 col0" >22.3413</td>
#       <td id="T_088fa_row5_col1" class="data row5 col1" >1201.4975</td>
#       <td id="T_088fa_row5_col2" class="data row5 col2" >34.6626</td>
#       <td id="T_088fa_row5_col3" class="data row5 col3" >0.9634</td>
#       <td id="T_088fa_row5_col4" class="data row5 col4" >0.3442</td>
#       <td id="T_088fa_row5_col5" class="data row5 col5" >0.3148</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_088fa_row6_col0" class="data row6 col0" >23.9322</td>
#       <td id="T_088fa_row6_col1" class="data row6 col1" >1451.6428</td>
#       <td id="T_088fa_row6_col2" class="data row6 col2" >38.1004</td>
#       <td id="T_088fa_row6_col3" class="data row6 col3" >0.9541</td>
#       <td id="T_088fa_row6_col4" class="data row6 col4" >0.3662</td>
#       <td id="T_088fa_row6_col5" class="data row6 col5" >0.3365</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_088fa_row7_col0" class="data row7 col0" >24.1619</td>
#       <td id="T_088fa_row7_col1" class="data row7 col1" >1763.1293</td>
#       <td id="T_088fa_row7_col2" class="data row7 col2" >41.9896</td>
#       <td id="T_088fa_row7_col3" class="data row7 col3" >0.9476</td>
#       <td id="T_088fa_row7_col4" class="data row7 col4" >0.3514</td>
#       <td id="T_088fa_row7_col5" class="data row7 col5" >0.3333</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_088fa_row8_col0" class="data row8 col0" >25.5477</td>
#       <td id="T_088fa_row8_col1" class="data row8 col1" >1769.7718</td>
#       <td id="T_088fa_row8_col2" class="data row8 col2" >42.0687</td>
#       <td id="T_088fa_row8_col3" class="data row8 col3" >0.9517</td>
#       <td id="T_088fa_row8_col4" class="data row8 col4" >0.3564</td>
#       <td id="T_088fa_row8_col5" class="data row8 col5" >0.3468</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_088fa_row9_col0" class="data row9 col0" >23.3415</td>
#       <td id="T_088fa_row9_col1" class="data row9 col1" >1500.3329</td>
#       <td id="T_088fa_row9_col2" class="data row9 col2" >38.7341</td>
#       <td id="T_088fa_row9_col3" class="data row9 col3" >0.9536</td>
#       <td id="T_088fa_row9_col4" class="data row9 col4" >0.3427</td>
#       <td id="T_088fa_row9_col5" class="data row9 col5" >0.3210</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_088fa_row10_col0" class="data row10 col0" >23.6746</td>
#       <td id="T_088fa_row10_col1" class="data row10 col1" >1525.4096</td>
#       <td id="T_088fa_row10_col2" class="data row10 col2" >38.9824</td>
#       <td id="T_088fa_row10_col3" class="data row10 col3" >0.9535</td>
#       <td id="T_088fa_row10_col4" class="data row10 col4" >0.3525</td>
#       <td id="T_088fa_row10_col5" class="data row10 col5" >0.3257</td>
#     </tr>
#     <tr>
#       <th id="T_088fa_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_088fa_row11_col0" class="data row11 col0" >0.8783</td>
#       <td id="T_088fa_row11_col1" class="data row11 col1" >186.1251</td>
#       <td id="T_088fa_row11_col2" class="data row11 col2" >2.4046</td>
#       <td id="T_088fa_row11_col3" class="data row11 col3" >0.0057</td>
#       <td id="T_088fa_row11_col4" class="data row11 col4" >0.0092</td>
#       <td id="T_088fa_row11_col5" class="data row11 col5" >0.0130</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ...or stack them (i.e., train a model to figure out how to blend the models):

# %%
stacked = stack_models(estimator_list = top5)
# Out:
# <style type="text/css">
# #T_18b71_row10_col0, #T_18b71_row10_col1, #T_18b71_row10_col2, #T_18b71_row10_col3, #T_18b71_row10_col4, #T_18b71_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_18b71_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18b71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18b71_row0_col0" class="data row0 col0" >22.7311</td>
#       <td id="T_18b71_row0_col1" class="data row0 col1" >1314.3397</td>
#       <td id="T_18b71_row0_col2" class="data row0 col2" >36.2538</td>
#       <td id="T_18b71_row0_col3" class="data row0 col3" >0.9597</td>
#       <td id="T_18b71_row0_col4" class="data row0 col4" >0.3790</td>
#       <td id="T_18b71_row0_col5" class="data row0 col5" >0.3354</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18b71_row1_col0" class="data row1 col0" >22.3846</td>
#       <td id="T_18b71_row1_col1" class="data row1 col1" >1259.7114</td>
#       <td id="T_18b71_row1_col2" class="data row1 col2" >35.4924</td>
#       <td id="T_18b71_row1_col3" class="data row1 col3" >0.9631</td>
#       <td id="T_18b71_row1_col4" class="data row1 col4" >0.3842</td>
#       <td id="T_18b71_row1_col5" class="data row1 col5" >0.3453</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18b71_row2_col0" class="data row2 col0" >23.5027</td>
#       <td id="T_18b71_row2_col1" class="data row2 col1" >1526.8705</td>
#       <td id="T_18b71_row2_col2" class="data row2 col2" >39.0752</td>
#       <td id="T_18b71_row2_col3" class="data row2 col3" >0.9527</td>
#       <td id="T_18b71_row2_col4" class="data row2 col4" >0.3831</td>
#       <td id="T_18b71_row2_col5" class="data row2 col5" >0.3558</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18b71_row3_col0" class="data row3 col0" >22.8336</td>
#       <td id="T_18b71_row3_col1" class="data row3 col1" >1584.4521</td>
#       <td id="T_18b71_row3_col2" class="data row3 col2" >39.8052</td>
#       <td id="T_18b71_row3_col3" class="data row3 col3" >0.9486</td>
#       <td id="T_18b71_row3_col4" class="data row3 col4" >0.3906</td>
#       <td id="T_18b71_row3_col5" class="data row3 col5" >0.3375</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18b71_row4_col0" class="data row4 col0" >23.8352</td>
#       <td id="T_18b71_row4_col1" class="data row4 col1" >1618.8898</td>
#       <td id="T_18b71_row4_col2" class="data row4 col2" >40.2354</td>
#       <td id="T_18b71_row4_col3" class="data row4 col3" >0.9488</td>
#       <td id="T_18b71_row4_col4" class="data row4 col4" >0.3906</td>
#       <td id="T_18b71_row4_col5" class="data row4 col5" >0.3338</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18b71_row5_col0" class="data row5 col0" >21.8042</td>
#       <td id="T_18b71_row5_col1" class="data row5 col1" >1154.6863</td>
#       <td id="T_18b71_row5_col2" class="data row5 col2" >33.9807</td>
#       <td id="T_18b71_row5_col3" class="data row5 col3" >0.9648</td>
#       <td id="T_18b71_row5_col4" class="data row5 col4" >0.3994</td>
#       <td id="T_18b71_row5_col5" class="data row5 col5" >0.3280</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_18b71_row6_col0" class="data row6 col0" >24.0683</td>
#       <td id="T_18b71_row6_col1" class="data row6 col1" >1452.2446</td>
#       <td id="T_18b71_row6_col2" class="data row6 col2" >38.1083</td>
#       <td id="T_18b71_row6_col3" class="data row6 col3" >0.9541</td>
#       <td id="T_18b71_row6_col4" class="data row6 col4" >0.4252</td>
#       <td id="T_18b71_row6_col5" class="data row6 col5" >0.4100</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_18b71_row7_col0" class="data row7 col0" >24.1733</td>
#       <td id="T_18b71_row7_col1" class="data row7 col1" >1675.5345</td>
#       <td id="T_18b71_row7_col2" class="data row7 col2" >40.9333</td>
#       <td id="T_18b71_row7_col3" class="data row7 col3" >0.9502</td>
#       <td id="T_18b71_row7_col4" class="data row7 col4" >0.4142</td>
#       <td id="T_18b71_row7_col5" class="data row7 col5" >0.3602</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_18b71_row8_col0" class="data row8 col0" >25.2140</td>
#       <td id="T_18b71_row8_col1" class="data row8 col1" >1686.1889</td>
#       <td id="T_18b71_row8_col2" class="data row8 col2" >41.0632</td>
#       <td id="T_18b71_row8_col3" class="data row8 col3" >0.9540</td>
#       <td id="T_18b71_row8_col4" class="data row8 col4" >0.4398</td>
#       <td id="T_18b71_row8_col5" class="data row8 col5" >0.3819</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_18b71_row9_col0" class="data row9 col0" >23.2423</td>
#       <td id="T_18b71_row9_col1" class="data row9 col1" >1449.0133</td>
#       <td id="T_18b71_row9_col2" class="data row9 col2" >38.0659</td>
#       <td id="T_18b71_row9_col3" class="data row9 col3" >0.9551</td>
#       <td id="T_18b71_row9_col4" class="data row9 col4" >0.3659</td>
#       <td id="T_18b71_row9_col5" class="data row9 col5" >0.3329</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_18b71_row10_col0" class="data row10 col0" >23.3789</td>
#       <td id="T_18b71_row10_col1" class="data row10 col1" >1472.1931</td>
#       <td id="T_18b71_row10_col2" class="data row10 col2" >38.3013</td>
#       <td id="T_18b71_row10_col3" class="data row10 col3" >0.9551</td>
#       <td id="T_18b71_row10_col4" class="data row10 col4" >0.3972</td>
#       <td id="T_18b71_row10_col5" class="data row10 col5" >0.3521</td>
#     </tr>
#     <tr>
#       <th id="T_18b71_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_18b71_row11_col0" class="data row11 col0" >0.9435</td>
#       <td id="T_18b71_row11_col1" class="data row11 col1" >172.0656</td>
#       <td id="T_18b71_row11_col2" class="data row11 col2" >2.2803</td>
#       <td id="T_18b71_row11_col3" class="data row11 col3" >0.0054</td>
#       <td id="T_18b71_row11_col4" class="data row11 col4" >0.0216</td>
#       <td id="T_18b71_row11_col5" class="data row11 col5" >0.0248</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we've trained a bunch of models (all the individual models + the ensemble + the blended models). Instead of sorting through all the models to pick what's best we can let PyCaret do it for us using the `automl` function:

# %%
best = automl(optimize='R2')

# %% [markdown]
# Here's the best model we found in the above process:

# %%
best
# Out:
# StackingRegressor(cv=KFold(n_splits=10, random_state=RandomState(MT19937) at 0x208FFED6B40,
#    shuffle=False),
#                   estimators=[('catboost',
#                                <catboost.core.CatBoostRegressor object at 0x00000208FF49E1C0>),
#                               ('xgboost',
#                                XGBRegressor(base_score=0.5, booster='gbtree',
#                                             colsample_bylevel=1,
#                                             colsample_bynode=1,
#                                             colsample_bytree=1,
#                                             enable_categorical=False, gamma=0,
#                                             gpu_id=-1, impor...
#                                                      max_samples=None,
#                                                      min_impurity_decrease=0.0,
#                                                      min_impurity_split=None,
#                                                      min_samples_leaf=1,
#                                                      min_samples_split=2,
#                                                      min_weight_fraction_leaf=0.0,
#                                                      n_estimators=100,
#                                                      n_jobs=-1, oob_score=False,
#                                                      random_state=2286,
#                                                      verbose=0,
#                                                      warm_start=False))],
#                   final_estimator=LinearRegression(copy_X=True,
#                                                    fit_intercept=True,
#                                                    n_jobs=-1, normalize=False),
#                   n_jobs=-1, passthrough=True, verbose=0)

# %% [markdown]
# # Evaluate models

# %% [markdown]
# Let's compute predictions and scores on the test data using the best model found above:

# %%
preds = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_70150_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70150_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70150_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_70150_row0_col1" class="data row0 col1" >22.9094</td>
#       <td id="T_70150_row0_col2" class="data row0 col2" >1400.7349</td>
#       <td id="T_70150_row0_col3" class="data row0 col3" >37.4264</td>
#       <td id="T_70150_row0_col4" class="data row0 col4" >0.9575</td>
#       <td id="T_70150_row0_col5" class="data row0 col5" >0.3850</td>
#       <td id="T_70150_row0_col6" class="data row0 col6" >0.3258</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Looks good. As always, one should take a closer look at the predictions and the features used by the model

# %%
plot_model(best, 'error')

# %%
plot_model(best)

# %% [markdown]
# A useful technique we haven't talked about yet is to plot so-called "learning curves": a plot of the performance versus the amount of training data given to the model. Among other things, such plots can indicate whether having more data (of the same kind) would increase performance, and provide an estimate of how much it would increase.

# %% [markdown]
# This takes some time to compute so I've attached the output as an image below.

# %%
plot_model(best, 'learning')

# %% [markdown]
# Learning curve:
#
# <img width=40% src="assets/learningcurves.png">

# %% [markdown]
# A way to get data-driven feature importances is to compute "permutation importance". Essentially: rank the features by observing the performance effects of random permutations of the entries in each feature column (separately). This is implemented in scikit-learn's `permutation_importance`.

# %%
from sklearn.inspection import permutation_importance

# %%
X_test = get_config(variable='X_test')
y_test = get_config(variable='y_test')

# %%
r = permutation_importance(best, X_test, y_test)

# %% [markdown]
# Here's the ranked list:

# %%
for i in r.importances_mean.argsort()[::-1]:
    if r.importances_mean[i] - 2 * r.importances_std[i] > 0:
        print(f"{X_test.columns[i]:<8}"
        f"{r.importances_mean[i]:.3f}"
        f" +/- {r.importances_std[i]:.3f}")
# Out:
# hr      1.390 +/- 0.011
# workingday_00.277 +/- 0.002
# yr_1    0.191 +/- 0.003
# temp    0.071 +/- 0.003
# hum     0.031 +/- 0.002
# season_10.027 +/- 0.001
# atemp   0.025 +/- 0.001
# weathersit_30.016 +/- 0.001
# weekday_50.009 +/- 0.000
# season_40.007 +/- 0.000
# weathersit_10.004 +/- 0.000
# weekday_60.004 +/- 0.000
# windspeed0.003 +/- 0.000
# weekday_00.003 +/- 0.000
# holiday_10.003 +/- 0.000
# dteday_month_90.002 +/- 0.000
# dteday_month_10.002 +/- 0.000
# dteday_month_120.002 +/- 0.000
# mnth_11 0.002 +/- 0.000
# dteday_weekday_00.002 +/- 0.000
# mnth_4  0.001 +/- 0.000
# weekday_40.001 +/- 0.000
# mnth_10 0.001 +/- 0.000
# dteday_month_30.001 +/- 0.000
# mnth_8  0.001 +/- 0.000
# season_20.001 +/- 0.000
# mnth_5  0.001 +/- 0.000
# mnth_2  0.001 +/- 0.000
# dteday_month_70.001 +/- 0.000
# weekday_20.001 +/- 0.000
# weekday_30.001 +/- 0.000
# season_30.001 +/- 0.000
# mnth_6  0.001 +/- 0.000
# weathersit_20.001 +/- 0.000
# dteday_is_month_start_00.000 +/- 0.000
# dteday_is_month_end_00.000 +/- 0.000

# %% [markdown]
# > That the `hr` is ranked high seems reasonable. That a year (`yr`) feature is ranked high should give us pause. If we wanted to construct a model that could be used to forecast demand we should've treated this as a time-series problem: trained the model on historical data and evaluated it on future data. In such a scenario, we would obtain different performance results (likely substantially lower) and be led to other models better suited for forecasting. However, as we don't know all the details about the situation generating the data, f.ex. whether the total number of bikes changed from year-to-year or whether there were efforts to recruit additional bike sharers, we can't really provide a very careful and comprehensive treatment of the forecasting problem.
#
# > Our example is **not set up as a forecasting problem**. We'll simply try to see if the provided features are able to produce reasonable predictions for bike demand for the instances in the data set (i.e., every hour given information from all earlier and later hours).

# %% [markdown]
# # Export pre-processing pipeline and model

# %% [markdown]
# Let's save the model for deployment in the next notebook:

# %% [markdown]
# First we finalize the model (meaning we use the test data as well for training the model [no reason to waste labelled data]):

# %%
final_model = finalize_model(best)

# %%
save_model(final_model, 'saved_model_161121')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['instant'],
#                                        id_columns=['instant'],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='cnt',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  nu...
#                                                                        min_impurity_decrease=0.0,
#                                                                        min_impurity_split=None,
#                                                                        min_samples_leaf=1,
#                                                                        min_samples_split=2,
#                                                                        min_weight_fraction_leaf=0.0,
#                                                                        n_estimators=100,
#                                                                        n_jobs=-1,
#                                                                        oob_score=False,
#                                                                        random_state=2286,
#                                                                        verbose=0,
#                                                                        warm_start=False))],
#                                     final_estimator=LinearRegression(copy_X=True,
#                                                                      fit_intercept=True,
#                                                                      n_jobs=-1,
#                                                                      normalize=False),
#                                     n_jobs=-1, passthrough=True, verbose=0)]],
#           verbose=False),
#  'saved_model_161121.pkl')
